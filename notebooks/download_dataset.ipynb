# %%
import pandas as pd
import os

# %%
#Carregando o dataset
url = 'https://raw.githubusercontent.com/atlantico-academy/datasets/main/titanic.csv'

df = pd.read_csv(url)
print(df.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#localizando o diretório
print(os.getcwd())
# Out:
# /home/luiz/workspace/atlantico-avanti/avanti-bootcamp-cdd/notebooks

# %%
#Salvando o arquivo data.csv
df.to_csv("/home/luiz/workspace/atlantico-avanti/avanti-bootcamp-cdd/data/raw/data.csv", index=False)
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#Identificando as Variáveis para classificação
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df["parch"]
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 886    0
# 887    0
# 888    2
# 889    0
# 890    0
# Name: parch, Length: 891, dtype: int64

# %%
dicionario = pd.DataFrame([
    {   "variavel": "survived",
        "descricao": "sobreviveu : 0 = não, 1 = sim",
        "tipo":"quantitativa",
        "subtipo":"discreta"
    },
    {   "variavel": "pclass",
        "descricao": "Classe do passageiro : 1 = primeiro, 2 = segunda, 3 = terceira",
        "tipo":"quantitativa",
        "subtipo":"discreta"
    },
    {   "variavel": "sex",
        "descricao": "Sexo do passageiro",
        "tipo":"qualitativa",
        "subtipo":"nominal"
    },
    {   "variavel": "age",
        "descricao": "Idade do passageiro",
        "tipo":"quantitativa",
        "subtipo":"discreta"
    },
    {   "variavel": "sibsp",
        "descricao": "Indica se tinha esposa(o) ou irmãos a bordo com o passageiro",
        "tipo":"quantitativa",
        "subtipo":"discreta"
    },
    {   "variavel": "parch",
        "descricao": "Número de pais/filhos a bordo com o passageiro",
        "tipo":"quantitativa",
        "subtipo":"discreta"
    },
    {   "variavel": "fare",
        "descricao": "Preço da passagem",
        "tipo":"quantitativa",
        "subtipo":"contínua"
    },
    {   "variavel": "embarked",
        "descricao": "Local do embarque do passageiro",
        "tipo":"qualitativa",
        "subtipo":"ordinal"
    },
    {   "variavel": "alive",
        "descricao": "Indica se o passageiro morreu ou viveu",
        "tipo":"qualitativa",
        "subtipo":"nomimal"
    },
    {   "variavel": "alone",
        "descricao": "Indica se o passageiro estava sozinho na viajem",
        "tipo":"qualitativa",
        "subtipo":"nomimal"
    },
    
])

dicionario.to_csv("/home/luiz/workspace/atlantico-avanti/avanti-bootcamp-cdd/data/external/dictionary.csv", index=False)
dicionario
# Out:
#    variavel                                          descricao          tipo  \
# 0  survived                      sobreviveu : 0 = não, 1 = sim  quantitativa
# 1    pclass  Classe do passageiro : 1 = primeiro, 2 = segun...  quantitativa
# 2       sex                                 Sexo do passageiro   qualitativa
# 3       age                                Idade do passageiro  quantitativa
# 4     sibsp  Indica se tinha esposa(o) ou irmãos a bordo co...  quantitativa
# 5     parch     Número de pais/filhos a bordo com o passageiro  quantitativa
# 6      fare                                  Preço da passagem  quantitativa
# 7  embarked                    Local do embarque do passageiro   qualitativa
# 8     alive             Indica se o passageiro morreu ou viveu   qualitativa
# 9     alone    Indica se o passageiro estava sozinho na viajem   qualitativa
#
#     subtipo
# 0  discreta
# 1  discreta
# 2   nominal
# 3  discreta
# 4  discreta
# 5  discreta
# 6  contínua
# 7   ordinal
# ...
